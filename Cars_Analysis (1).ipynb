# %% [markdown]
# ## ASSIGNMENT 2:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("cars.csv",encoding='latin1')

# %%
df.head()
# Out:
#                Model   mpg  cyl   disp     hp  drat     wt   qsec   vs   am  \
# 0          Mazda RX4  21.0  6.0  160.0  110.0  3.90  2.620  16.46  0.0  1.0
# 1      Mazda RX4 Wag  21.0  6.0  160.0  110.0  3.90  2.875  17.02  0.0  1.0
# 2         Datsun 710  22.8  4.0  108.0   93.0  3.85  2.320  18.61  1.0  1.0
# 3     Hornet 4 Drive  21.4  6.0  258.0  110.0  3.08  3.215  19.44  1.0  0.0
# 4  Hornet Sportabout  18.7  8.0  360.0  175.0  3.15  3.440  17.02  0.0  0.0
#
#    gear  carb
# 0   4.0   4.0
# 1   4.0   4.0
# 2   4.0   1.0
# 3   3.0   1.0
# 4   3.0   2.0

# %%
#Fetching number of rows and column
print ("(row,column)")
df.shape
# Out:
# (row,column)
# (33, 12)

# %%
df.describe(include = 'all')
# Out:
#             Model        mpg        cyl        disp          hp       drat  \
# count          33  32.000000  32.000000   32.000000   32.000000  32.000000
# unique         33        NaN        NaN         NaN         NaN        NaN
# top     Mazda RX4        NaN        NaN         NaN         NaN        NaN
# freq            1        NaN        NaN         NaN         NaN        NaN
# mean          NaN  20.090625   6.187500  230.721875  146.687500   3.596563
# std           NaN   6.026948   1.785922  123.938694   68.562868   0.534679
# min           NaN  10.400000   4.000000   71.100000   52.000000   2.760000
# 25%           NaN  15.425000   4.000000  120.825000   96.500000   3.080000
# 50%           NaN  19.200000   6.000000  196.300000  123.000000   3.695000
# 75%           NaN  22.800000   8.000000  326.000000  180.000000   3.920000
# max           NaN  33.900000   8.000000  472.000000  335.000000   4.930000
#
# ...

# %%
relevant_columns = df[['mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear', 'carb']]
# Calculate the mean for each column
mean_values = relevant_columns.mean()
print("Mean:\n", mean_values)
print()
# Calculate the median for each column
median_values = relevant_columns.median()
print("Median:\n", median_values)
print()
# Calculate the standard deviation for each column
std_values = relevant_columns.std()
print("Standard Deviation:\n", std_values)
# Out:
# Mean:
#  mpg      20.090625
# cyl       6.187500
# disp    230.721875
# hp      146.687500
# drat      3.596563
# wt        3.217250
# qsec     17.848750
# vs        0.437500
# am        0.406250
# gear      3.687500
# carb      2.812500
# dtype: float64
#
# Median:
#  mpg      19.200
# cyl       6.000
# disp    196.300
# hp      123.000
# drat      3.695
# wt        3.325
# qsec     17.710
# vs        0.000
# am        0.000
# gear      4.000
# carb      2.000
# dtype: float64
#
# Standard Deviation:
#  mpg       6.026948
# cyl       1.785922
# disp    123.938694
# hp       68.562868
# drat      0.534679
# wt        0.978457
# qsec      1.786943
# vs        0.504016
# am        0.498991
# gear      0.737804
# carb      1.615200
# dtype: float64

# %%
import seaborn as sns
for i in relevant_columns:
    df[i] = df[i].fillna(df[i].mean())
    plt.figure(figsize=(4, 2))
    sns.boxplot(df[i],color = "gray")
    plt.title('Interpretation of 25%ile and 75%ile')
    plt.show()
    print("25% = ",np.percentile(db[i], 25))
    print("75% = ",np.percentile(db[i], 75))
# Out:
# 25% =  15.5
# 75% =  22.8
# 25% =  4.0
# 75% =  8.0
# 25% =  121.0
# 75% =  318.0
# 25% =  97.0
# 75% =  180.0
# 25% =  3.08
# 75% =  3.92
# 25% =  2.62
# 75% =  3.57
# 25% =  16.9
# 75% =  18.9
# 25% =  0.0
# 75% =  1.0
# 25% =  0.0
# 75% =  1.0
# 25% =  3.0
# 75% =  4.0
# 25% =  2.0
# 75% =  4.0

# %% [markdown]
# ## Assignment 3:

# %%
# Setting up the plotting style
sns.set(style="whitegrid")

# Figure 1: Distribution of MPG (Miles per Gallon)
plt.figure(figsize=(4, 2))
sns.histplot(df['mpg'], kde=True, bins=10, color='skyblue')
plt.title("Distribution of Miles per Gallon (MPG)", fontsize=14)
plt.xlabel("MPG", fontsize=12)
plt.ylabel("Frequency", fontsize=12)
plt.show()

# Figure 2: Scatter plot of Horsepower (hp) vs. Weight (wt)
plt.figure(figsize=(4, 2))
sns.scatterplot(x=df['wt'], y=df['hp'], hue=df['cyl'], palette="viridis", s=100)
plt.title("Horsepower vs. Weight", fontsize=14)
plt.xlabel("Weight (1000 lbs)", fontsize=12)
plt.ylabel("Horsepower", fontsize=12)
plt.legend(title="Cylinders")
plt.show()

# Figure 3: Boxplot of MPG by Cylinder Count
plt.figure(figsize=(4, 2))
sns.boxplot(x=df['cyl'], y=df['mpg'])
plt.title("MPG by Cylinder Count", fontsize=14)
plt.xlabel("Number of Cylinders", fontsize=12)
plt.ylabel("Miles per Gallon (MPG)", fontsize=12)
plt.show()

# Figure 4: Pairplot of selected features
selected_features = ['mpg', 'hp', 'wt', 'disp']
sns.pairplot(df[selected_features], diag_kind="kde", corner=True,)
plt.suptitle("Pairwise Relationships Between Selected Features", y=1.02, fontsize=14)
plt.show()
